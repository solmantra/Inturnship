# %%
import numpy as np
import pandas as pd

# %%
# !pip install bs4
# !pip install requests

# %%
from bs4 import BeautifulSoup
import requests

# %%
pg1=requests.get('https://www.imdb.com/list/ls056092300/')

# %%
pg1
# Out:
# <Response [403]>

# %%
print('Responses 403 so cannot scrap')
# Out:
# Responses 403 so cannot scrap

# %%
pg2=requests.get('https://www.patreon.com/coreyms')

# %%
pg2
# Out:
# <Response [200]>

# %%
sp2=BeautifulSoup(pg2.content)
sp2
# Out:
# <!DOCTYPE html>
# <html><head><meta charset="utf-8"/><script type="text/javascript">
#             window.patreonConfig = {"apiServer":"www.patreon.com/api","nionDisableDefaultIncludes":true,"formattingLocale":"en-US","eventLoggingPlatform":"Web","isWebView":false,"pathname":"/\u003cstring:campaign_identifier\u003e","is_impersonating":false,"csrfSignature":"GwxXo1dGu5buFnJgDvEj1az25DsR6PCU0izmyKOGqkw"};
# ...

# %%
hdg=sp2.find('div',class_="sc-bBHxTw iloeMK")
dt=sp2.find('div',class_="sc-lgu5zg-0 dXpjXs")
content=sp2.find('div',class_="sc-jrQzAO gnnDyW")

# %%
hdg=[]

for i in sp2.find_all('div',class_="sc-bBHxTw iloeMK"):
    hdg.append(i.text)
    
dt=[]

for i in sp2.find_all('div',class_="sc-lgu5zg-0 dXpjXs"):
    dt.append(i.text)

content=[]

for i in sp2.find_all('div',class_="sc-jrQzAO gnnDyW"):
    content.append(i.text)
    
df=pd.DataFrame({'Titles':hdg,'Date':dt,'Content':content})
df
# Out:
# Empty DataFrame
# Columns: [Titles, Date, Content]
# Index: []

# %%
print("Not getting why it is empty")

# %%
pg3=requests.get('https://www.nobroker.in/')
pg3
# Out:
# <Response [200]>

# %%
sp3=BeautifulSoup(pg3.content)
sp3
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta content="794951570520699" property="fb:pages"/>
# <link href="https://www.nobroker.in" rel="canonical"/>
# <link href="//www.googletagmanager.com" rel="dns-prefetch preconnect"/>
# <link href="//www.google-analytics.com" rel="dns-prefetch preconnect"/>
# <link href="//assets.nobroker.in" rel="dns-prefetch"/>
# <link href="//images.nobroker.in" rel="dns-prefetch"/>
# <link href="https://assets.adobedtm.com" rel="dns-prefetch preconnect"/>
# <link href="//assets.nobroker.in/static/img/favicon.png" id="favicon" rel="shortcut icon"/>
# <link href="https://images.nobroker.in/static/img/fav64.png" rel="apple-touch-icon"/>
# <link href="https://hs.nobroker.in" rel="dns-prefetch preconnect"/>
# <!--<meta charset="utf-8"/>-->
# <meta charset="utf-8"/>
# <meta content="app-id=com.nobroker.app&amp;referrer=utm_source%3Dnobroker%26utm_medium%3DmobileWeb" name="google-play-app"/>
# ...

# %%
loc_indi= sp2.find('div',class_="h-1.1p flex items-center justify-center relative")
loc_jaya= sp2.find('div',class_="h-1.1p flex items-center justify-center relative")

# %%
pg4=requests.get('https://www.bewakoof.com/bestseller?sort=popular%20')

# %%
pg5=requests.get('https://www.cnbc.com/world/?region=world')

# %%
pg5=requests.get('(https://www.keaipublishing.com/en/journals/artificial-intelligence-in-agriculture/most-downloadedarticles/')
